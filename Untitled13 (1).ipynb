# %%
import cv2

# %%
img = cv2.imread('Screenshot 2020-09-08 at 6.28.15 PM.png')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
faces_dataset = face_cascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in faces_dataset:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=1174x1214 at 0x7F2F43565630>
# -1
